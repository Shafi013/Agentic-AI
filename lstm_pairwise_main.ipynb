# %%
# ======================= LSTM PAIRWISE AGENTS + MQTT LIVE =======================
import os
import json
import time
from collections import deque
from typing import List, Dict, Any, Optional, Tuple

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import LSTM, Dropout

import paho.mqtt.client as mqtt
from paho.mqtt.client import CallbackAPIVersion

# ---------------------------------------------------------------------
# PATHS
# ---------------------------------------------------------------------
DATA_DIR = r"C:\Users\Muckbul\Desktop\agenticAI"
ARTIFACTS_ROOT = DATA_DIR  # where models + scaler + feature_names go

# ---------------------------------------------------------------------
# MQTT CONFIG
# ---------------------------------------------------------------------
MQTT_BROKER = "localhost"
MQTT_PORT = 1883

TOPIC_BASE = "fault_detection/report/pairwise"
LIVE_FEATURE_TOPIC = "fault_detection/live/features"
LIVE_RESULT_TOPIC = "fault_detection/live/result"

# ---------------------------------------------------------------------
# TRAINING / MODEL CONFIG
# ---------------------------------------------------------------------
TIME_STEPS = 10
SEED, TEST_SIZE, VAL_SIZE = 42, 0.2, 0.2
BATCH, EPOCHS, LR = 128, 20, 1e-4

RUN_TRAINING = True   # set to False when models are already trained

# use only first N rows from each OM file for training
MAX_ROWS_PER_FILE = 500

# if you want to only use data after a certain time, set a float here;
# otherwise keep as None (your OM1..OM8 already contain faults from start).
FAULT_START_TIME: Optional[float] = None  # e.g. 500.0 if needed

rng = np.random.RandomState(SEED)
tf.random.set_seed(SEED)

# CLASS NAMES (OM0..OM8)
CLASS_NAMES = [f"OM{i}" for i in range(0, 9)]  # 9 classes total
# All unordered pairs (i < j)
PAIR_LIST: List[Tuple[str, str]] = [
    (CLASS_NAMES[i], CLASS_NAMES[j])
    for i in range(len(CLASS_NAMES))
    for j in range(i + 1, len(CLASS_NAMES))
]


# ---------------------------------------------------------------------
# BASIC UTILITIES
# ---------------------------------------------------------------------
def load_numeric(
    path: str,
    max_rows: Optional[int] = None,
    fault_start_time: Optional[float] = None,
) -> pd.DataFrame:
    """
    Load numeric columns from Excel/CSV.
    If 'Time' column exists and fault_start_time is not None, keep only
    rows with Time >= fault_start_time. Then keep only numeric columns.
    Optionally limit to 'max_rows' rows (after filtering).
    """
    ext = os.path.splitext(path)[1].lower()
    if ext in (".xlsx", ".xls"):
        df = pd.read_excel(path)
    elif ext == ".csv":
        df = pd.read_csv(path)
    else:
        raise ValueError(f"Unsupported file type: {ext}")

    # Force-convert Time to numeric (if present)
    if "Time" in df.columns:
        df["Time"] = pd.to_numeric(df["Time"], errors="coerce")
        df = df.dropna(subset=["Time"])
        if fault_start_time is not None:
            df = df[df["Time"] >= fault_start_time].copy()

    # Numeric columns only
    num = df.select_dtypes(include=[np.number]).copy()
    num = num.replace([np.inf, -np.inf], np.nan).ffill().bfill()

    if max_rows is not None and len(num) > max_rows:
        num = num.iloc[:max_rows].copy()

    return num


def find_file(base: str) -> Optional[str]:
    p_xlsx = os.path.join(DATA_DIR, f"{base}.xlsx")
    p_csv = os.path.join(DATA_DIR, f"{base}.csv")
    if os.path.exists(p_xlsx):
        return p_xlsx
    if os.path.exists(p_csv):
        return p_csv
    return None


def create_sequences(X: np.ndarray, y: np.ndarray, time_steps: int = 10, step: int = 1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        Xs.append(X[i: i + time_steps])
        ys.append(y[i + time_steps - 1])
    return np.array(Xs), np.array(ys)


def oversample_indices(idx_array: np.ndarray, n_target: int) -> np.ndarray:
    if len(idx_array) == 0:
        return idx_array
    if n_target <= len(idx_array):
        return rng.choice(idx_array, size=n_target, replace=False)
    extra = rng.choice(idx_array, size=n_target - len(idx_array), replace=True)
    return np.concatenate([idx_array, extra], axis=0)


def make_topic(exp_name: str) -> str:
    safe = exp_name.replace(" ", "_").replace("(", "").replace(")", "")
    return f"{TOPIC_BASE}/{safe}"


# ---------------------------------------------------------------------
# MQTT CALLBACKS (for training summary only)
# ---------------------------------------------------------------------
def on_connect(client, userdata, flags, reason_code, properties=None):
    print(f"[MQTT] Connected rc={reason_code}")


def on_disconnect(client, userdata, flags, reason_code, properties=None):
    print(f"[MQTT] Disconnected rc={reason_code}")
    # For paho v2, reason_code may be an object; treat non-zero as error
    try:
        rc_val = int(reason_code)
    except Exception:
        rc_val = getattr(reason_code, "value", 0)

    if rc_val != 0:
        print("[MQTT] Trying to reconnect...")
        try:
            client.reconnect()
        except Exception as e:
            print(f"[MQTT] Reconnect failed: {e}")



def on_message(client, userdata, msg):
    # Not used here; keep for completeness.
    pass


def publish_mqtt_report(client, exp_name: str, accuracy: float, report_dict: dict):
    topic = make_topic(exp_name)
    payload = {
        "agent": exp_name,
        "model_type": "LSTM_pairwise",
        "overall_test_accuracy": round(float(accuracy), 4),
        "weighted_f1": round(float(report_dict["weighted avg"]["f1-score"]), 4),
        "timestamp": pd.Timestamp.now().isoformat(),
    }
    msg = json.dumps(payload, ensure_ascii=False)
    print(f"[MQTT] Publish summary -> {topic}")
    if client:
        client.publish(topic, msg, qos=1)


# ---------------------------------------------------------------------
# GLOBAL SCALER (shared by all pairwise agents)
# ---------------------------------------------------------------------
def build_global_scaler() -> Tuple[StandardScaler, List[str]]:
    """
    Load all OM0..OM8 data (limited to MAX_ROWS_PER_FILE) and fit one
    StandardScaler on the concatenated dataset. Save mean/scale and
    feature_names to ARTIFACTS_ROOT.
    """
    X_all_parts = []
    feature_names: Optional[List[str]] = None

    for cls in CLASS_NAMES:
        p = find_file(cls)
        if p is None:
            print(f"[GLOBAL SCALER] WARNING: file for {cls} not found; skipping.")
            continue
        df = load_numeric(p, max_rows=MAX_ROWS_PER_FILE, fault_start_time=FAULT_START_TIME)
        if df.empty:
            print(f"[GLOBAL SCALER] WARNING: {cls} loaded but empty; skipping.")
            continue

        if feature_names is None:
            feature_names = df.columns.tolist()
        else:
            df = df.reindex(columns=feature_names)

        X_all_parts.append(df.to_numpy())

    if not X_all_parts or feature_names is None:
        raise RuntimeError("[GLOBAL SCALER] No data loaded from OM files.")

    X_all = np.concatenate(X_all_parts, axis=0)
    X_all = np.nan_to_num(X_all, nan=0.0)

    scaler = StandardScaler().fit(X_all)

    scaler_obj = {"mean": scaler.mean_.tolist(), "scale": scaler.scale_.tolist()}
    os.makedirs(ARTIFACTS_ROOT, exist_ok=True)
    with open(os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json"), "w") as f:
        json.dump(scaler_obj, f)
    with open(os.path.join(ARTIFACTS_ROOT, "feature_names.json"), "w") as f:
        json.dump(feature_names, f)

    print("[GLOBAL SCALER] Fitted scaler on all classes.")
    print(f"[GLOBAL SCALER] Features: {feature_names}")

    return scaler, feature_names


# ---------------------------------------------------------------------
# TRAIN ONE PAIRWISE AGENT: (cls_a vs cls_b)
# ---------------------------------------------------------------------
def train_pair_agent(
    client,
    scaler: StandardScaler,
    feature_names: List[str],
    cls_a: str,
    cls_b: str,
) -> Optional[Dict[str, Any]]:
    """
    Train LSTM for pair (cls_a vs cls_b).
    Label y=0 for cls_a, y=1 for cls_b.
    """
    exp_name = f"Agent {cls_a}_vs_{cls_b}"
    print("\n" + "=" * 80)
    print(f"TRAINING: {exp_name}")
    print("=" * 80)

    # ---- Load data for both classes ----
    X_parts, y_parts = [], []

    for cls, label in [(cls_a, 0), (cls_b, 1)]:
        p = find_file(cls)
        if p is None:
            print(f"[PAIR {cls_a} vs {cls_b}] File for {cls} not found; skipping pair.")
            return None
        df = load_numeric(p, max_rows=MAX_ROWS_PER_FILE, fault_start_time=FAULT_START_TIME)
        if df.empty:
            print(f"[PAIR {cls_a} vs {cls_b}] Empty data for {cls}; skipping pair.")
            return None

        # align columns
        df = df.reindex(columns=feature_names)
        X = df.to_numpy()
        X = np.nan_to_num(X, nan=0.0)

        # use global scaler
        X_scaled = scaler.transform(X)

        X_parts.append(X_scaled)
        y_parts.append(np.full(len(df), label, dtype=int))

    X_all = np.concatenate(X_parts, axis=0)
    y_all = np.concatenate(y_parts, axis=0)

    # ---- Create sequences ----
    X_seq, y_seq = create_sequences(X_all, y_all, time_steps=TIME_STEPS)
    print(
        f"[PAIR {cls_a} vs {cls_b}] X_seq={X_seq.shape}, "
        f"y_seq={y_seq.shape}, #0={(y_seq==0).sum()}, #1={(y_seq==1).sum()}"
    )
    if len(X_seq) < 2 * TIME_STEPS:
        print(f"[PAIR {cls_a} vs {cls_b}] Not enough sequences; skipping.")
        return None

    # ---- Split train/val/test ----
    X_tr, X_te, y_tr, y_te = train_test_split(
        X_seq, y_seq, test_size=TEST_SIZE, random_state=SEED, stratify=y_seq
    )
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_tr, y_tr, test_size=VAL_SIZE, random_state=SEED, stratify=y_tr
    )

    # ---- Balance classes by oversampling ----
    idx = np.arange(len(y_tr))
    idx_a = idx[y_tr == 0]
    idx_b = idx[y_tr == 1]
    target = max(len(idx_a), len(idx_b))
    idx_a_bal = oversample_indices(idx_a, target)
    idx_b_bal = oversample_indices(idx_b, target)
    idx_final = np.concatenate([idx_a_bal, idx_b_bal])
    rng.shuffle(idx_final)

    X_tr_bal = X_tr[idx_final]
    y_tr_bal = y_tr[idx_final]

    print(
        f"[PAIR {cls_a} vs {cls_b}] After balancing: "
        f"#0={(y_tr_bal==0).sum()}, #1={(y_tr_bal==1).sum()}"
    )

    # ---- Build & train LSTM ----
    n_features = X_tr_bal.shape[2]
    model = Sequential(
        [
            layers.Input(shape=(TIME_STEPS, n_features)),
            LSTM(64, return_sequences=True),
            Dropout(0.2),
            LSTM(32, return_sequences=False),
            Dropout(0.2),
            layers.Dense(32, activation="relu"),
            layers.Dense(1, activation="sigmoid"),
        ],
        name=f"LSTM_{cls_a}_vs_{cls_b}",
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )

    print(f"[PAIR {cls_a} vs {cls_b}] Training LSTM...")
    model.fit(
        X_tr_bal,
        y_tr_bal,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH,
        verbose=1,
    )

    # ---- Evaluate ----
    probs_te = model.predict(X_te, verbose=0).flatten()
    y_pred_te = (probs_te > 0.5).astype(int)

    report = classification_report(
        y_te,
        y_pred_te,
        target_names=[cls_a, cls_b],
        output_dict=True,
        zero_division=0,
    )
    test_acc = report["accuracy"]
    print(f"[PAIR {cls_a} vs {cls_b}] Test accuracy: {test_acc:.4f}")

    # ---- Save model ----
    safe_name = exp_name.replace(" ", "_").replace("(", "").replace(")", "")
    save_dir = os.path.join(ARTIFACTS_ROOT, f"{safe_name}_artifacts")
    os.makedirs(save_dir, exist_ok=True)
    model.save(os.path.join(save_dir, "model_saved.keras"))

    publish_mqtt_report(client, exp_name, test_acc, report)

    return {"Pair": f"{cls_a}_vs_{cls_b}", "TestAcc": test_acc}


# ---------------------------------------------------------------------
# LIVE INFERENCE (pairwise voting)
# ---------------------------------------------------------------------
class LiveInference:
    def __init__(self):
        self.feature_names: List[str] = []
        self.scaler_mean: np.ndarray = None
        self.scaler_scale: np.ndarray = None

        # list of (cls_a, cls_b, model)
        self.pair_models: List[Tuple[str, str, tf.keras.Model]] = []

        self.history_buffer = deque(maxlen=TIME_STEPS)
        self.last_time: Optional[float] = None
        self.have_seen_any: bool = False

    def load_artifacts(self) -> bool:
        scaler_path = os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json")
        feat_path = os.path.join(ARTIFACTS_ROOT, "feature_names.json")

        if not (os.path.exists(scaler_path) and os.path.exists(feat_path)):
            print("[LIVE] Shared scaler/feature_names not found.")
            return False

        with open(scaler_path, "r") as f:
            scaler_obj = json.load(f)
        with open(feat_path, "r") as f:
            self.feature_names = json.load(f)

        self.scaler_mean = np.array(scaler_obj["mean"], dtype=float)
        self.scaler_scale = np.array(scaler_obj["scale"], dtype=float)
        self.scaler_scale[self.scaler_scale == 0] = 1.0

        # load all available pairwise models
        for cls_a, cls_b in PAIR_LIST:
            exp_name = f"Agent {cls_a}_vs_{cls_b}"
            folder = os.path.join(
                ARTIFACTS_ROOT,
                f"{exp_name.replace(' ', '_').replace('(', '').replace(')', '')}_artifacts",
            )
            model_path = os.path.join(folder, "model_saved.keras")
            if os.path.exists(model_path):
                print(f"[LIVE] Loading model for pair {cls_a} vs {cls_b}")
                model = tf.keras.models.load_model(model_path)
                self.pair_models.append((cls_a, cls_b, model))

        if not self.pair_models:
            print("[LIVE] No pairwise models loaded.")
            return False

        print(f"[LIVE] Using features ({len(self.feature_names)}): {self.feature_names}")
        print(f"[LIVE] Loaded {len(self.pair_models)} pairwise agents.")
        return True

    def reset_buffer(self):
        self.history_buffer.clear()
        self.last_time = None
        self.have_seen_any = False
        print("[LIVE] Buffer reset (new simulation).")

    def preprocess_single_vector(self, feat_dict: Dict[str, Any]) -> np.ndarray:
        x = np.zeros(len(self.feature_names), dtype=float)
        for i, name in enumerate(self.feature_names):
            try:
                x[i] = float(feat_dict.get(name, 0.0))
            except Exception:
                x[i] = 0.0
        return (x - self.scaler_mean) / self.scaler_scale

    def predict_fault(self) -> Dict[str, Any]:
        seq_data = np.array(self.history_buffer)  # (T,F)
        X_in = np.expand_dims(seq_data, axis=0)   # (1,T,F)

        votes = {cls: 0 for cls in CLASS_NAMES}
        score_sums = {cls: 0.0 for cls in CLASS_NAMES}

        for cls_a, cls_b, model in self.pair_models:
            prob_b = float(model.predict(X_in, verbose=0)[0, 0])
            prob_a = 1.0 - prob_b

            if prob_b >= 0.5:
                winner = cls_b
                prob = prob_b
            else:
                winner = cls_a
                prob = prob_a

            votes[winner] += 1
            score_sums[winner] += prob

        # pick class with maximum votes; break ties with summed score
        best_cls = None
        best_votes = -1
        best_score = -1.0
        for cls in CLASS_NAMES:
            v = votes[cls]
            s = score_sums[cls]
            if v > best_votes or (v == best_votes and s > best_score):
                best_cls = cls
                best_votes = v
                best_score = s

        winner = best_cls if best_cls is not None else "OM0"
        # normalize probability: average of winner's scores
        if best_votes > 0:
            winner_prob = best_score / best_votes
        else:
            winner_prob = 0.5

        # build agent_scores per class (normalized)
        agent_scores = {}
        total_votes = sum(votes.values()) + 1e-9
        for cls in CLASS_NAMES:
            agent_scores[cls] = votes[cls] / total_votes

        return {"agent_scores": agent_scores, "winner": winner, "winner_prob": winner_prob}

    def on_feature_message(self, client, userdata, msg):
        try:
            data = json.loads(msg.payload.decode())
            feat_dict = data.get("features", {})

            # ---- Time handling ----
            t = None
            if "Time" in feat_dict:
                try:
                    t = float(feat_dict["Time"])
                except Exception:
                    t = None

            # Detect new run once when Time ~ 0
            if t is not None:
                if (not self.have_seen_any) and t <= 1e-3:
                    self.reset_buffer()
                self.have_seen_any = True
                self.last_time = t

            # ---- Normal processing ----
            x_s = self.preprocess_single_vector(feat_dict)
            self.history_buffer.append(x_s)

            if len(self.history_buffer) < TIME_STEPS:
                print(f"[LIVE] Buffering... ({len(self.history_buffer)}/{TIME_STEPS})")
                return

            result = self.predict_fault()
            payload = {
                "timestamp": pd.Timestamp.now().isoformat(),
                "winner": result["winner"],
                "winner_prob": round(result["winner_prob"], 4),
                "agent_scores": {
                    k: round(v, 4) for k, v in result["agent_scores"].items()
                },
                "buffer_status": "READY",
            }
            out_msg = json.dumps(payload, ensure_ascii=False)
            print(f"[LIVE] Result: {result['winner']} ({result['winner_prob']:.2f})")
            client.publish(LIVE_RESULT_TOPIC, out_msg, qos=1)

        except Exception as e:
            print(f"[LIVE] Error: {e}")


def start_live_inference(client):
    live = LiveInference()
    if not live.load_artifacts():
        return

    client.message_callback_add(LIVE_FEATURE_TOPIC, live.on_feature_message)
    client.subscribe(LIVE_FEATURE_TOPIC)
    print(f"[LIVE] Listening on {LIVE_FEATURE_TOPIC}...")

    try:
        while True:
            time.sleep(1.0)
    except KeyboardInterrupt:
        print("[LIVE] Stopping live loop.")


# ---------------------------------------------------------------------
# MAIN
# ---------------------------------------------------------------------
def main():
    if not os.path.isdir(DATA_DIR):
        print(f"[ERROR] DATA_DIR '{DATA_DIR}' invalid.")
        return

    client = mqtt.Client(
        client_id=f"FaultDetection_Pairwise_{int(time.time())}",
        protocol=mqtt.MQTTv311,
        callback_api_version=CallbackAPIVersion.VERSION2,
    )
    client.on_connect = on_connect
    client.on_disconnect = on_disconnect
    client.on_message = on_message

    client.reconnect_delay_set(min_delay=1, max_delay=5)
client.connect(MQTT_BROKER, MQTT_PORT, keepalive=300)
client.loop_start()

try:
        # 1) Build global scaler (or load if already exists)
        if RUN_TRAINING:
            scaler, feature_names = build_global_scaler()
        else:
            # load existing scaler + features
            with open(os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json"), "r") as f:
                sc_obj = json.load(f)
            with open(os.path.join(ARTIFACTS_ROOT, "feature_names.json"), "r") as f:
                feature_names = json.load(f)
            scaler = StandardScaler()
            scaler.mean_ = np.array(sc_obj["mean"], dtype=float)
            scaler.scale_ = np.array(sc_obj["scale"], dtype=float)
            scaler.var_ = scaler.scale_ ** 2

        # 2) Train pairwise agents
        if RUN_TRAINING:
            results = []
            for cls_a, cls_b in PAIR_LIST:
                info = train_pair_agent(client, scaler, feature_names, cls_a, cls_b)
                if info:
                    results.append(info)
            if results:
                print("\n[TRAIN] Pairwise summary:")
                print(pd.DataFrame(results))

        # 3) Live inference loop
        start_live_inference(client)

    finally:
        client.loop_stop()
        client.disconnect()
        print("[MAIN] Done.")


if __name__ == "__main__":
    main()
# Out:
#   File <tokenize>:599
#     finally:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import lstm_pairwise_main

# %%
lstm_pairwise_main.RUN_TRAINING = False
lstm_pairwise_main.main()
# Out:
# [MQTT] Connected rc=Success
# [LIVE] Loading model for pair OM0 vs OM1
# [LIVE] Loading model for pair OM0 vs OM2
# [LIVE] Loading model for pair OM0 vs OM3
# [LIVE] Loading model for pair OM0 vs OM4
# [LIVE] Loading model for pair OM0 vs OM5
# [LIVE] Loading model for pair OM0 vs OM6
# [LIVE] Loading model for pair OM0 vs OM7
# [LIVE] Loading model for pair OM0 vs OM8
# [MQTT] Disconnected rc=Unspecified error
# [LIVE] Loading model for pair OM1 vs OM2
# [LIVE] Loading model for pair OM1 vs OM3
# [LIVE] Loading model for pair OM1 vs OM4
# [LIVE] Loading model for pair OM1 vs OM5
# [LIVE] Loading model for pair OM1 vs OM6
# [LIVE] Loading model for pair OM1 vs OM7
# [LIVE] Loading model for pair OM1 vs OM8
# [LIVE] Loading model for pair OM2 vs OM3
# [MQTT] Connected rc=Success
# [LIVE] Loading model for pair OM2 vs OM4
# [LIVE] Loading model for pair OM2 vs OM5
# [LIVE] Loading model for pair OM2 vs OM6
# [LIVE] Loading model for pair OM2 vs OM7
# [LIVE] Loading model for pair OM2 vs OM8
# [MQTT] Disconnected rc=Unspecified error
# [LIVE] Loading model for pair OM3 vs OM4
# [LIVE] Loading model for pair OM3 vs OM5
# [LIVE] Loading model for pair OM3 vs OM6
# [LIVE] Loading model for pair OM3 vs OM7
# [LIVE] Loading model for pair OM3 vs OM8
# [LIVE] Loading model for pair OM4 vs OM5
# [MQTT] Connected rc=Success
# [LIVE] Loading model for pair OM4 vs OM6
# [LIVE] Loading model for pair OM4 vs OM7
# [LIVE] Loading model for pair OM4 vs OM8
# [LIVE] Loading model for pair OM5 vs OM6
# [LIVE] Loading model for pair OM5 vs OM7
# [LIVE] Loading model for pair OM5 vs OM8
# [LIVE] Loading model for pair OM6 vs OM7
# [MQTT] Disconnected rc=Unspecified error
# [LIVE] Loading model for pair OM6 vs OM8
# [LIVE] Loading model for pair OM7 vs OM8
# [LIVE] Using features (18): ['Time', 'Data_ 1', 'Data_ 2', 'Data_ 3', 'Data_ 4', 'Data_ 5', 'Data_ 6', 'Data_ 7', 'Data_ 8', 'Data_ 9', 'Data_10', 'Data_11', 'Data_12', 'Data_13', 'Data_14', 'Data_15', 'Data_16', 'Data_17']
# [LIVE] Loaded 36 pairwise agents.
# [LIVE] Listening on fault_detection/live/features...
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [MQTT] Connected rc=Success
# [MQTT] Disconnected rc=Unspecified error
# [LIVE] Stopping live loop.
# [MAIN] Done.

# %%
# ======================= LSTM PAIRWISE AGENTS + MQTT LIVE =======================
import os
import json
import time
from collections import deque
from typing import List, Dict, Any, Optional, Tuple

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

import tensorflow as tf
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import LSTM, Dropout

import paho.mqtt.client as mqtt
from paho.mqtt.client import CallbackAPIVersion

# ---------------------------------------------------------------------
# PATHS  (CHANGE THIS TO YOUR FOLDER IF NEEDED)
# ---------------------------------------------------------------------
DATA_DIR = r"C:\Users\Muckbul\Desktop\agenticAI"  # <-- EDIT IF NEEDED
ARTIFACTS_ROOT = DATA_DIR  # where models + scaler + feature_names go

# ---------------------------------------------------------------------
# MQTT CONFIG
# ---------------------------------------------------------------------
MQTT_BROKER = "localhost"
MQTT_PORT = 1883

TOPIC_BASE = "fault_detection/report/pairwise"
LIVE_FEATURE_TOPIC = "fault_detection/live/features"
LIVE_RESULT_TOPIC = "fault_detection/live/result"

# ---------------------------------------------------------------------
# TRAINING / MODEL CONFIG
# ---------------------------------------------------------------------
TIME_STEPS = 10
SEED, TEST_SIZE, VAL_SIZE = 42, 0.2, 0.2
BATCH, EPOCHS, LR = 128, 20, 1e-4

RUN_TRAINING = True   # set False when models already trained

# use only first N rows from each OM file for training
MAX_ROWS_PER_FILE = 500

# if you want only data after a certain time, set a float here
FAULT_START_TIME: Optional[float] = None  # e.g. 500.0, else None

rng = np.random.RandomState(SEED)
tf.random.set_seed(SEED)

# CLASS NAMES (OM0..OM8)
CLASS_NAMES = [f"OM{i}" for i in range(0, 9)]  # 9 classes total
# All unordered pairs (i < j)
PAIR_LIST: List[Tuple[str, str]] = [
    (CLASS_NAMES[i], CLASS_NAMES[j])
    for i in range(len(CLASS_NAMES))
    for j in range(i + 1, len(CLASS_NAMES))
]


# ---------------------------------------------------------------------
# BASIC UTILITIES
# ---------------------------------------------------------------------
def load_numeric(
    path: str,
    max_rows: Optional[int] = None,
    fault_start_time: Optional[float] = None,
) -> pd.DataFrame:
    """
    Load numeric columns from Excel/CSV.
    If 'Time' column exists and fault_start_time is not None, keep only
    rows with Time >= fault_start_time. Then keep only numeric columns.
    Optionally limit to 'max_rows' rows (after filtering).
    """
    ext = os.path.splitext(path)[1].lower()
    if ext in (".xlsx", ".xls"):
        df = pd.read_excel(path)
    elif ext == ".csv":
        df = pd.read_csv(path)
    else:
        raise ValueError(f"Unsupported file type: {ext}")

    # Force-convert Time to numeric (if present)
    if "Time" in df.columns:
        df["Time"] = pd.to_numeric(df["Time"], errors="coerce")
        df = df.dropna(subset=["Time"])
        if fault_start_time is not None:
            df = df[df["Time"] >= fault_start_time].copy()

    # Numeric columns only
    num = df.select_dtypes(include=[np.number]).copy()
    num = num.replace([np.inf, -np.inf], np.nan).ffill().bfill()

    if max_rows is not None and len(num) > max_rows:
        num = num.iloc[:max_rows].copy()

    return num


def find_file(base: str) -> Optional[str]:
    p_xlsx = os.path.join(DATA_DIR, f"{base}.xlsx")
    p_csv = os.path.join(DATA_DIR, f"{base}.csv")
    if os.path.exists(p_xlsx):
        return p_xlsx
    if os.path.exists(p_csv):
        return p_csv
    return None


def create_sequences(X: np.ndarray, y: np.ndarray, time_steps: int = 10, step: int = 1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        Xs.append(X[i: i + time_steps])
        ys.append(y[i + time_steps - 1])
    return np.array(Xs), np.array(ys)


def oversample_indices(idx_array: np.ndarray, n_target: int) -> np.ndarray:
    if len(idx_array) == 0:
        return idx_array
    if n_target <= len(idx_array):
        return rng.choice(idx_array, size=n_target, replace=False)
    extra = rng.choice(idx_array, size=n_target - len(idx_array), replace=True)
    return np.concatenate([idx_array, extra], axis=0)


def make_topic(exp_name: str) -> str:
    safe = exp_name.replace(" ", "_").replace("(", "").replace(")", "")
    return f"{TOPIC_BASE}/{safe}"


# ---------------------------------------------------------------------
# MQTT CALLBACKS
# ---------------------------------------------------------------------
def on_connect(client, userdata, flags, reason_code, properties=None):
    print(f"[MQTT] Connected rc={reason_code}")


def on_disconnect(client, userdata, flags, reason_code, properties=None):
    print(f"[MQTT] Disconnected rc={reason_code}")
    # try to interpret reason_code as int (for paho v2)
    try:
        rc_val = int(reason_code)
    except Exception:
        rc_val = getattr(reason_code, "value", 0)

    # non-zero means unexpected disconnect -> try to reconnect
    if rc_val != 0:
        print("[MQTT] Trying to reconnect...")
        try:
            client.reconnect()
        except Exception as e:
            print(f"[MQTT] Reconnect failed: {e}")


def on_message(client, userdata, msg):
    # Not used here; kept for completeness
    pass


def publish_mqtt_report(client, exp_name: str, accuracy: float, report_dict: dict):
    topic = make_topic(exp_name)
    payload = {
        "agent": exp_name,
        "model_type": "LSTM_pairwise",
        "overall_test_accuracy": round(float(accuracy), 4),
        "weighted_f1": round(float(report_dict["weighted avg"]["f1-score"]), 4),
        "timestamp": pd.Timestamp.now().isoformat(),
    }
    msg = json.dumps(payload, ensure_ascii=False)
    print(f"[MQTT] Publish summary -> {topic}")
    if client:
        try:
            client.publish(topic, msg, qos=1)
        except Exception as e:
            print(f"[MQTT] Publish error: {e}")


# ---------------------------------------------------------------------
# GLOBAL SCALER (shared by all pairwise agents)
# ---------------------------------------------------------------------
def build_global_scaler() -> Tuple[StandardScaler, List[str]]:
    """
    Load all OM0..OM8 data (limited to MAX_ROWS_PER_FILE) and fit one
    StandardScaler on the concatenated dataset. Save mean/scale and
    feature_names to ARTIFACTS_ROOT.
    """
    X_all_parts = []
    feature_names: Optional[List[str]] = None

    for cls in CLASS_NAMES:
        p = find_file(cls)
        if p is None:
            print(f"[GLOBAL SCALER] WARNING: file for {cls} not found; skipping.")
            continue
        df = load_numeric(p, max_rows=MAX_ROWS_PER_FILE, fault_start_time=FAULT_START_TIME)
        if df.empty:
            print(f"[GLOBAL SCALER] WARNING: {cls} loaded but empty; skipping.")
            continue

        if feature_names is None:
            feature_names = df.columns.tolist()
        else:
            df = df.reindex(columns=feature_names)

        X_all_parts.append(df.to_numpy())

    if not X_all_parts or feature_names is None:
        raise RuntimeError("[GLOBAL SCALER] No data loaded from OM files.")

    X_all = np.concatenate(X_all_parts, axis=0)
    X_all = np.nan_to_num(X_all, nan=0.0)

    scaler = StandardScaler().fit(X_all)

    scaler_obj = {"mean": scaler.mean_.tolist(), "scale": scaler.scale_.tolist()}
    os.makedirs(ARTIFACTS_ROOT, exist_ok=True)
    with open(os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json"), "w") as f:
        json.dump(scaler_obj, f)
    with open(os.path.join(ARTIFACTS_ROOT, "feature_names.json"), "w") as f:
        json.dump(feature_names, f)

    print("[GLOBAL SCALER] Fitted scaler on all classes.")
    print(f"[GLOBAL SCALER] Features: {feature_names}")

    return scaler, feature_names


# ---------------------------------------------------------------------
# TRAIN ONE PAIRWISE AGENT: (cls_a vs cls_b)
# ---------------------------------------------------------------------
def train_pair_agent(
    client,
    scaler: StandardScaler,
    feature_names: List[str],
    cls_a: str,
    cls_b: str,
) -> Optional[Dict[str, Any]]:
    """
    Train LSTM for pair (cls_a vs cls_b).
    Label y=0 for cls_a, y=1 for cls_b.
    """
    exp_name = f"Agent {cls_a}_vs_{cls_b}"
    print("\n" + "=" * 80)
    print(f"TRAINING: {exp_name}")
    print("=" * 80)

    # ---- Load data for both classes ----
    X_parts, y_parts = [], []

    for cls, label in [(cls_a, 0), (cls_b, 1)]:
        p = find_file(cls)
        if p is None:
            print(f"[PAIR {cls_a} vs {cls_b}] File for {cls} not found; skipping pair.")
            return None
        df = load_numeric(p, max_rows=MAX_ROWS_PER_FILE, fault_start_time=FAULT_START_TIME)
        if df.empty:
            print(f"[PAIR {cls_a} vs {cls_b}] Empty data for {cls}; skipping pair.")
            return None

        # align columns
        df = df.reindex(columns=feature_names)
        X = df.to_numpy()
        X = np.nan_to_num(X, nan=0.0)

        # use global scaler
        X_scaled = scaler.transform(X)

        X_parts.append(X_scaled)
        y_parts.append(np.full(len(df), label, dtype=int))

    X_all = np.concatenate(X_parts, axis=0)
    y_all = np.concatenate(y_parts, axis=0)

    # ---- Create sequences ----
    X_seq, y_seq = create_sequences(X_all, y_all, time_steps=TIME_STEPS)
    print(
        f"[PAIR {cls_a} vs {cls_b}] X_seq={X_seq.shape}, "
        f"y_seq={y_seq.shape}, #0={(y_seq == 0).sum()}, #1={(y_seq == 1).sum()}"
    )
    if len(X_seq) < 2 * TIME_STEPS:
        print(f"[PAIR {cls_a} vs {cls_b}] Not enough sequences; skipping.")
        return None

    # ---- Split train/val/test ----
    X_tr, X_te, y_tr, y_te = train_test_split(
        X_seq, y_seq, test_size=TEST_SIZE, random_state=SEED, stratify=y_seq
    )
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_tr, y_tr, test_size=VAL_SIZE, random_state=SEED, stratify=y_tr
    )

    # ---- Balance classes by oversampling ----
    idx = np.arange(len(y_tr))
    idx_a = idx[y_tr == 0]
    idx_b = idx[y_tr == 1]
    target = max(len(idx_a), len(idx_b))
    idx_a_bal = oversample_indices(idx_a, target)
    idx_b_bal = oversample_indices(idx_b, target)
    idx_final = np.concatenate([idx_a_bal, idx_b_bal])
    rng.shuffle(idx_final)

    X_tr_bal = X_tr[idx_final]
    y_tr_bal = y_tr[idx_final]

    print(
        f"[PAIR {cls_a} vs {cls_b}] After balancing: "
        f"#0={(y_tr_bal == 0).sum()}, #1={(y_tr_bal == 1).sum()}"
    )

    # ---- Build & train LSTM ----
    n_features = X_tr_bal.shape[2]
    model = Sequential(
        [
            layers.Input(shape=(TIME_STEPS, n_features)),
            LSTM(64, return_sequences=True),
            Dropout(0.2),
            LSTM(32, return_sequences=False),
            Dropout(0.2),
            layers.Dense(32, activation="relu"),
            layers.Dense(1, activation="sigmoid"),
        ],
        name=f"LSTM_{cls_a}_vs_{cls_b}",
    )

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )

    print(f"[PAIR {cls_a} vs {cls_b}] Training LSTM...")
    model.fit(
        X_tr_bal,
        y_tr_bal,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH,
        verbose=1,
    )

    # ---- Evaluate ----
    probs_te = model.predict(X_te, verbose=0).flatten()
    y_pred_te = (probs_te > 0.5).astype(int)

    report = classification_report(
        y_te,
        y_pred_te,
        target_names=[cls_a, cls_b],
        output_dict=True,
        zero_division=0,
    )
    test_acc = report["accuracy"]
    print(f"[PAIR {cls_a} vs {cls_b}] Test accuracy: {test_acc:.4f}")

    # ---- Save model ----
    safe_name = exp_name.replace(" ", "_").replace("(", "").replace(")", "")
    save_dir = os.path.join(ARTIFACTS_ROOT, f"{safe_name}_artifacts")
    os.makedirs(save_dir, exist_ok=True)
    model.save(os.path.join(save_dir, "model_saved.keras"))

    publish_mqtt_report(client, exp_name, test_acc, report)

    return {"Pair": f"{cls_a}_vs_{cls_b}", "TestAcc": test_acc}


# ---------------------------------------------------------------------
# LIVE INFERENCE (pairwise voting)
# ---------------------------------------------------------------------
class LiveInference:
    def __init__(self):
        self.feature_names: List[str] = []
        self.scaler_mean: np.ndarray = None
        self.scaler_scale: np.ndarray = None

        # list of (cls_a, cls_b, model)
        self.pair_models: List[Tuple[str, str, tf.keras.Model]] = []

        self.history_buffer = deque(maxlen=TIME_STEPS)
        self.last_time: Optional[float] = None
        self.have_seen_any: bool = False

    def load_artifacts(self) -> bool:
        scaler_path = os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json")
        feat_path = os.path.join(ARTIFACTS_ROOT, "feature_names.json")

        if not (os.path.exists(scaler_path) and os.path.exists(feat_path)):
            print("[LIVE] Shared scaler/feature_names not found.")
            return False

        with open(scaler_path, "r") as f:
            scaler_obj = json.load(f)
        with open(feat_path, "r") as f:
            self.feature_names = json.load(f)

        self.scaler_mean = np.array(scaler_obj["mean"], dtype=float)
        self.scaler_scale = np.array(scaler_obj["scale"], dtype=float)
        self.scaler_scale[self.scaler_scale == 0] = 1.0

        # load all available pairwise models
        for cls_a, cls_b in PAIR_LIST:
            exp_name = f"Agent {cls_a}_vs_{cls_b}"
            folder = os.path.join(
                ARTIFACTS_ROOT,
                f"{exp_name.replace(' ', '_').replace('(', '').replace(')', '')}_artifacts",
            )
            model_path = os.path.join(folder, "model_saved.keras")
            if os.path.exists(model_path):
                print(f"[LIVE] Loading model for pair {cls_a} vs {cls_b}")
                model = tf.keras.models.load_model(model_path)
                self.pair_models.append((cls_a, cls_b, model))

        if not self.pair_models:
            print("[LIVE] No pairwise models loaded.")
            return False

        print(f"[LIVE] Using features ({len(self.feature_names)}): {self.feature_names}")
        print(f"[LIVE] Loaded {len(self.pair_models)} pairwise agents.")
        return True

    def reset_buffer(self):
        self.history_buffer.clear()
        self.last_time = None
        self.have_seen_any = False
        print("[LIVE] Buffer reset (new simulation).")

    def preprocess_single_vector(self, feat_dict: Dict[str, Any]) -> np.ndarray:
        x = np.zeros(len(self.feature_names), dtype=float)
        for i, name in enumerate(self.feature_names):
            try:
                x[i] = float(feat_dict.get(name, 0.0))
            except Exception:
                x[i] = 0.0
        return (x - self.scaler_mean) / self.scaler_scale

    def predict_fault(self) -> Dict[str, Any]:
        seq_data = np.array(self.history_buffer)  # (T,F)
        X_in = np.expand_dims(seq_data, axis=0)   # (1,T,F)

        votes = {cls: 0 for cls in CLASS_NAMES}
        score_sums = {cls: 0.0 for cls in CLASS_NAMES}

        for cls_a, cls_b, model in self.pair_models:
            prob_b = float(model.predict(X_in, verbose=0)[0, 0])
            prob_a = 1.0 - prob_b

            if prob_b >= 0.5:
                winner = cls_b
                prob = prob_b
            else:
                winner = cls_a
                prob = prob_a

            votes[winner] += 1
            score_sums[winner] += prob

        # pick class with maximum votes; break ties with summed score
        best_cls = None
        best_votes = -1
        best_score = -1.0
        for cls in CLASS_NAMES:
            v = votes[cls]
            s = score_sums[cls]
            if v > best_votes or (v == best_votes and s > best_score):
                best_cls = cls
                best_votes = v
                best_score = s

        winner = best_cls if best_cls is not None else "OM0"
        # normalize probability: average of winner's scores
        if best_votes > 0:
            winner_prob = best_score / best_votes
        else:
            winner_prob = 0.5

        # build agent_scores per class (normalized)
        agent_scores = {}
        total_votes = sum(votes.values()) + 1e-9
        for cls in CLASS_NAMES:
            agent_scores[cls] = votes[cls] / total_votes

        return {"agent_scores": agent_scores, "winner": winner, "winner_prob": winner_prob}

    def on_feature_message(self, client, userdata, msg):
        try:
            data = json.loads(msg.payload.decode())
            feat_dict = data.get("features", {})

            # ---- Time handling ----
            t = None
            if "Time" in feat_dict:
                try:
                    t = float(feat_dict["Time"])
                except Exception:
                    t = None

            # Detect new run once when Time ~ 0
            if t is not None:
                if (not self.have_seen_any) and t <= 1e-3:
                    self.reset_buffer()
                self.have_seen_any = True
                self.last_time = t

            # ---- Normal processing ----
            x_s = self.preprocess_single_vector(feat_dict)
            self.history_buffer.append(x_s)

            if len(self.history_buffer) < TIME_STEPS:
                print(f"[LIVE] Buffering... ({len(self.history_buffer)}/{TIME_STEPS})")
                return

            result = self.predict_fault()
            payload = {
                "timestamp": pd.Timestamp.now().isoformat(),
                "winner": result["winner"],
                "winner_prob": round(result["winner_prob"], 4),
                "agent_scores": {
                    k: round(v, 4) for k, v in result["agent_scores"].items()
                },
                "buffer_status": "READY",
            }
            out_msg = json.dumps(payload, ensure_ascii=False)
            print(f"[LIVE] Result: {result['winner']} ({result['winner_prob']:.2f})")
            client.publish(LIVE_RESULT_TOPIC, out_msg, qos=1)

        except Exception as e:
            print(f"[LIVE] Error: {e}")


def start_live_inference(client):
    """
    Attach callbacks and block in a simple loop.
    Call this after training / loading models.
    """
    live = LiveInference()
    if not live.load_artifacts():
        return

    client.message_callback_add(LIVE_FEATURE_TOPIC, live.on_feature_message)
    client.subscribe(LIVE_FEATURE_TOPIC)
    print(f"[LIVE] Listening on {LIVE_FEATURE_TOPIC}...")

    try:
        while True:
            time.sleep(1.0)
    except KeyboardInterrupt:
        print("[LIVE] Stopping live loop.")


# ---------------------------------------------------------------------
# MAIN
# ---------------------------------------------------------------------
def main():
    if not os.path.isdir(DATA_DIR):
        print(f"[ERROR] DATA_DIR '{DATA_DIR}' invalid.")
        return

    # ------- MQTT CLIENT (stable) -------
    unique_id = f"FaultDetection_Pairwise_{int(time.time())}"

    client = mqtt.Client(
        client_id=unique_id,
        protocol=mqtt.MQTTv311,
        callback_api_version=CallbackAPIVersion.VERSION2,
    )
    client.on_connect = on_connect
    client.on_disconnect = on_disconnect
    client.on_message = on_message

    # reconnection behaviour
    client.reconnect_delay_set(min_delay=1, max_delay=5)

    # connect and start background loop
    client.connect(MQTT_BROKER, MQTT_PORT, keepalive=300)
    client.loop_start()

    try:
        # 1) Build global scaler (or load if already exists)
        if RUN_TRAINING:
            scaler, feature_names = build_global_scaler()
        else:
            with open(os.path.join(ARTIFACTS_ROOT, "scaler_mean_std.json"), "r") as f:
                sc_obj = json.load(f)
            with open(os.path.join(ARTIFACTS_ROOT, "feature_names.json"), "r") as f:
                feature_names = json.load(f)
            scaler = StandardScaler()
            scaler.mean_ = np.array(sc_obj["mean"], dtype=float)
            scaler.scale_ = np.array(sc_obj["scale"], dtype=float)
            scaler.var_ = scaler.scale_ ** 2

        # 2) Train pairwise agents
        if RUN_TRAINING:
            results = []
            for cls_a, cls_b in PAIR_LIST:
                info = train_pair_agent(client, scaler, feature_names, cls_a, cls_b)
                if info:
                    results.append(info)
            if results:
                print("\n[TRAIN] Pairwise summary:")
                print(pd.DataFrame(results))

        # 3) Live inference loop
        start_live_inference(client)

    finally:
        client.loop_stop()
        client.disconnect()
        print("[MAIN] Done.")


if __name__ == "__main__":
    main()
# Out:
# [MQTT] Connected rc=Success
# [GLOBAL SCALER] Fitted scaler on all classes.
# [GLOBAL SCALER] Features: ['Time', 'Data_ 1', 'Data_ 2', 'Data_ 3', 'Data_ 4', 'Data_ 5', 'Data_ 6', 'Data_ 7', 'Data_ 8', 'Data_ 9', 'Data_10', 'Data_11', 'Data_12', 'Data_13', 'Data_14', 'Data_15', 'Data_16', 'Data_17']
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM1
# ================================================================================
# [PAIR OM0 vs OM1] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM1] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM1] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.3433 - loss: 0.7126 - val_accuracy: 0.2830 - val_loss: 0.7093
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4107 - loss: 0.7049 - val_accuracy: 0.5031 - val_loss: 0.6996
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4953 - loss: 0.6954 - val_accuracy: 0.5031 - val_loss: 0.6909
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5110 - loss: 0.6900 - val_accuracy: 0.5346 - val_loss: 0.6829
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5705 - loss: 0.6812 - val_accuracy: 0.6478 - val_loss: 0.6752
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6176 - loss: 0.6764 - val_accuracy: 0.7484 - val_loss: 0.6677
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6834 - loss: 0.6693 - val_accuracy: 0.7736 - val_loss: 0.6603
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7351 - loss: 0.6631 - val_accuracy: 0.7799 - val_loss: 0.6528
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7774 - loss: 0.6550 - val_accuracy: 0.8365 - val_loss: 0.6451
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8150 - loss: 0.6488 - val_accuracy: 0.8679 - val_loss: 0.6372
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8088 - loss: 0.6424 - val_accuracy: 0.8994 - val_loss: 0.6291
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8683 - loss: 0.6342 - val_accuracy: 0.9182 - val_loss: 0.6208
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8621 - loss: 0.6280 - val_accuracy: 0.9497 - val_loss: 0.6121
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8762 - loss: 0.6191 - val_accuracy: 0.9686 - val_loss: 0.6027
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8997 - loss: 0.6104 - val_accuracy: 0.9811 - val_loss: 0.5928
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9060 - loss: 0.6008 - val_accuracy: 0.9874 - val_loss: 0.5821
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9232 - loss: 0.5907 - val_accuracy: 0.9874 - val_loss: 0.5707
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9216 - loss: 0.5826 - val_accuracy: 0.9874 - val_loss: 0.5583
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9295 - loss: 0.5696 - val_accuracy: 0.9874 - val_loss: 0.5449
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9342 - loss: 0.5563 - val_accuracy: 0.9874 - val_loss: 0.5306
# [PAIR OM0 vs OM1] Test accuracy: 0.9798
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM1
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM2
# ================================================================================
# [PAIR OM0 vs OM2] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM2] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM2] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.6207 - loss: 0.6389 - val_accuracy: 0.6478 - val_loss: 0.6229
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6897 - loss: 0.6165 - val_accuracy: 0.7862 - val_loss: 0.5999
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7524 - loss: 0.5955 - val_accuracy: 0.8428 - val_loss: 0.5776
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8245 - loss: 0.5750 - val_accuracy: 0.8994 - val_loss: 0.5560
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8699 - loss: 0.5580 - val_accuracy: 0.9245 - val_loss: 0.5357
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8903 - loss: 0.5409 - val_accuracy: 0.9686 - val_loss: 0.5167
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9138 - loss: 0.5230 - val_accuracy: 0.9874 - val_loss: 0.4989
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9404 - loss: 0.5075 - val_accuracy: 0.9748 - val_loss: 0.4823
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9530 - loss: 0.4930 - val_accuracy: 0.9748 - val_loss: 0.4667
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9420 - loss: 0.4775 - val_accuracy: 0.9748 - val_loss: 0.4520
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9608 - loss: 0.4663 - val_accuracy: 0.9748 - val_loss: 0.4381
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9545 - loss: 0.4522 - val_accuracy: 0.9748 - val_loss: 0.4251
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9592 - loss: 0.4423 - val_accuracy: 0.9748 - val_loss: 0.4128
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9592 - loss: 0.4312 - val_accuracy: 0.9748 - val_loss: 0.4010
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9639 - loss: 0.4175 - val_accuracy: 0.9748 - val_loss: 0.3899
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9592 - loss: 0.4070 - val_accuracy: 0.9748 - val_loss: 0.3790
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9592 - loss: 0.3958 - val_accuracy: 0.9748 - val_loss: 0.3683
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9608 - loss: 0.3882 - val_accuracy: 0.9748 - val_loss: 0.3578
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9608 - loss: 0.3800 - val_accuracy: 0.9748 - val_loss: 0.3475
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9592 - loss: 0.3679 - val_accuracy: 0.9748 - val_loss: 0.3373
# [PAIR OM0 vs OM2] Test accuracy: 0.9596
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM2
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM3
# ================================================================================
# [PAIR OM0 vs OM3] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM3] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM3] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.3401 - loss: 0.7548 - val_accuracy: 0.3270 - val_loss: 0.7436
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3495 - loss: 0.7357 - val_accuracy: 0.3774 - val_loss: 0.7222
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4216 - loss: 0.7140 - val_accuracy: 0.4906 - val_loss: 0.7036
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.4812 - loss: 0.7004 - val_accuracy: 0.6667 - val_loss: 0.6866
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6019 - loss: 0.6874 - val_accuracy: 0.8931 - val_loss: 0.6724
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7257 - loss: 0.6734 - val_accuracy: 0.9308 - val_loss: 0.6598
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7743 - loss: 0.6645 - val_accuracy: 0.9748 - val_loss: 0.6481
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7978 - loss: 0.6573 - val_accuracy: 1.0000 - val_loss: 0.6371
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8401 - loss: 0.6443 - val_accuracy: 1.0000 - val_loss: 0.6260
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9232 - loss: 0.6316 - val_accuracy: 1.0000 - val_loss: 0.6145
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9263 - loss: 0.6227 - val_accuracy: 1.0000 - val_loss: 0.6028
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9326 - loss: 0.6140 - val_accuracy: 0.9937 - val_loss: 0.5905
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9577 - loss: 0.6024 - val_accuracy: 0.9937 - val_loss: 0.5777
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9639 - loss: 0.5899 - val_accuracy: 0.9937 - val_loss: 0.5640
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9671 - loss: 0.5793 - val_accuracy: 0.9937 - val_loss: 0.5496
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9765 - loss: 0.5612 - val_accuracy: 0.9937 - val_loss: 0.5344
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9812 - loss: 0.5472 - val_accuracy: 0.9937 - val_loss: 0.5183
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9828 - loss: 0.5332 - val_accuracy: 0.9937 - val_loss: 0.5013
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9828 - loss: 0.5147 - val_accuracy: 0.9937 - val_loss: 0.4832
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9812 - loss: 0.4998 - val_accuracy: 0.9937 - val_loss: 0.4642
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000140A36ED4E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [PAIR OM0 vs OM3] Test accuracy: 0.9949
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM3
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM4
# ================================================================================
# [PAIR OM0 vs OM4] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM4] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM4] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.5298 - loss: 0.6938 - val_accuracy: 0.5157 - val_loss: 0.6929
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5094 - loss: 0.6928 - val_accuracy: 0.5220 - val_loss: 0.6922
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5455 - loss: 0.6905 - val_accuracy: 0.4969 - val_loss: 0.6914
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4984 - loss: 0.6928 - val_accuracy: 0.5094 - val_loss: 0.6907
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5016 - loss: 0.6930 - val_accuracy: 0.5472 - val_loss: 0.6900
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5423 - loss: 0.6908 - val_accuracy: 0.5786 - val_loss: 0.6892
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5690 - loss: 0.6903 - val_accuracy: 0.5975 - val_loss: 0.6885
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5455 - loss: 0.6899 - val_accuracy: 0.6415 - val_loss: 0.6877
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5721 - loss: 0.6880 - val_accuracy: 0.6855 - val_loss: 0.6868
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5956 - loss: 0.6881 - val_accuracy: 0.7107 - val_loss: 0.6859
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5940 - loss: 0.6876 - val_accuracy: 0.7421 - val_loss: 0.6849
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5862 - loss: 0.6879 - val_accuracy: 0.7484 - val_loss: 0.6839
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6285 - loss: 0.6852 - val_accuracy: 0.7484 - val_loss: 0.6827
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6442 - loss: 0.6832 - val_accuracy: 0.7610 - val_loss: 0.6815
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6364 - loss: 0.6824 - val_accuracy: 0.7736 - val_loss: 0.6802
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6364 - loss: 0.6818 - val_accuracy: 0.7925 - val_loss: 0.6788
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6458 - loss: 0.6817 - val_accuracy: 0.7925 - val_loss: 0.6772
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6646 - loss: 0.6795 - val_accuracy: 0.7987 - val_loss: 0.6754
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6489 - loss: 0.6783 - val_accuracy: 0.7862 - val_loss: 0.6733
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6818 - loss: 0.6764 - val_accuracy: 0.7925 - val_loss: 0.6710
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000140ABF76020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [PAIR OM0 vs OM4] Test accuracy: 0.7879
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM4
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM5
# ================================================================================
# [PAIR OM0 vs OM5] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM5] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM5] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.5768 - loss: 0.6608 - val_accuracy: 0.4906 - val_loss: 0.6467
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6489 - loss: 0.6480 - val_accuracy: 0.6415 - val_loss: 0.6302
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7351 - loss: 0.6325 - val_accuracy: 0.9182 - val_loss: 0.6141
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7994 - loss: 0.6186 - val_accuracy: 0.9811 - val_loss: 0.5985
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8809 - loss: 0.6027 - val_accuracy: 0.9811 - val_loss: 0.5839
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9342 - loss: 0.5895 - val_accuracy: 0.9811 - val_loss: 0.5706
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9655 - loss: 0.5782 - val_accuracy: 0.9811 - val_loss: 0.5576
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9639 - loss: 0.5656 - val_accuracy: 0.9811 - val_loss: 0.5448
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9765 - loss: 0.5543 - val_accuracy: 0.9811 - val_loss: 0.5320
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9765 - loss: 0.5415 - val_accuracy: 0.9811 - val_loss: 0.5190
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9812 - loss: 0.5281 - val_accuracy: 0.9811 - val_loss: 0.5060
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9765 - loss: 0.5147 - val_accuracy: 0.9811 - val_loss: 0.4929
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9796 - loss: 0.5039 - val_accuracy: 0.9811 - val_loss: 0.4797
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9796 - loss: 0.4920 - val_accuracy: 0.9811 - val_loss: 0.4665
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9765 - loss: 0.4810 - val_accuracy: 0.9811 - val_loss: 0.4533
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9812 - loss: 0.4654 - val_accuracy: 0.9811 - val_loss: 0.4400
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9812 - loss: 0.4527 - val_accuracy: 0.9811 - val_loss: 0.4267
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9781 - loss: 0.4383 - val_accuracy: 0.9811 - val_loss: 0.4133
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9812 - loss: 0.4261 - val_accuracy: 0.9811 - val_loss: 0.3999
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9812 - loss: 0.4131 - val_accuracy: 0.9811 - val_loss: 0.3865
# [PAIR OM0 vs OM5] Test accuracy: 0.9798
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM5
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM6
# ================================================================================
# [PAIR OM0 vs OM6] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM6] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM6] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.5345 - loss: 0.6907 - val_accuracy: 0.7610 - val_loss: 0.6802
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6740 - loss: 0.6759 - val_accuracy: 0.7799 - val_loss: 0.6646
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7868 - loss: 0.6621 - val_accuracy: 0.7799 - val_loss: 0.6506
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8323 - loss: 0.6506 - val_accuracy: 0.8176 - val_loss: 0.6378
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8495 - loss: 0.6407 - val_accuracy: 0.8553 - val_loss: 0.6257
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8934 - loss: 0.6281 - val_accuracy: 0.9119 - val_loss: 0.6140
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9185 - loss: 0.6159 - val_accuracy: 0.9497 - val_loss: 0.6016
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9185 - loss: 0.6054 - val_accuracy: 0.9811 - val_loss: 0.5885
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9373 - loss: 0.5919 - val_accuracy: 0.9748 - val_loss: 0.5747
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9357 - loss: 0.5810 - val_accuracy: 0.9748 - val_loss: 0.5604
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9357 - loss: 0.5662 - val_accuracy: 0.9686 - val_loss: 0.5455
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9467 - loss: 0.5532 - val_accuracy: 0.9623 - val_loss: 0.5303
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9404 - loss: 0.5401 - val_accuracy: 0.9497 - val_loss: 0.5146
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9342 - loss: 0.5246 - val_accuracy: 0.9497 - val_loss: 0.4987
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9295 - loss: 0.5098 - val_accuracy: 0.9497 - val_loss: 0.4825
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9310 - loss: 0.4929 - val_accuracy: 0.9434 - val_loss: 0.4661
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9201 - loss: 0.4814 - val_accuracy: 0.9371 - val_loss: 0.4496
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9216 - loss: 0.4640 - val_accuracy: 0.9371 - val_loss: 0.4332
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9248 - loss: 0.4490 - val_accuracy: 0.9371 - val_loss: 0.4167
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9232 - loss: 0.4346 - val_accuracy: 0.9308 - val_loss: 0.4003
# [PAIR OM0 vs OM6] Test accuracy: 0.9394
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM6
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM7
# ================================================================================
# [PAIR OM0 vs OM7] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM7] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM7] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.5564 - loss: 0.6712 - val_accuracy: 0.5031 - val_loss: 0.6616
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6144 - loss: 0.6592 - val_accuracy: 0.6981 - val_loss: 0.6465
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7492 - loss: 0.6448 - val_accuracy: 0.9937 - val_loss: 0.6316
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8495 - loss: 0.6308 - val_accuracy: 0.9937 - val_loss: 0.6168
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9216 - loss: 0.6182 - val_accuracy: 0.9937 - val_loss: 0.6019
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9718 - loss: 0.6037 - val_accuracy: 0.9937 - val_loss: 0.5868
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9781 - loss: 0.5921 - val_accuracy: 0.9937 - val_loss: 0.5715
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9875 - loss: 0.5768 - val_accuracy: 0.9937 - val_loss: 0.5562
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9843 - loss: 0.5627 - val_accuracy: 0.9937 - val_loss: 0.5408
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9922 - loss: 0.5469 - val_accuracy: 0.9937 - val_loss: 0.5252
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9937 - loss: 0.5354 - val_accuracy: 0.9937 - val_loss: 0.5092
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9922 - loss: 0.5174 - val_accuracy: 0.9937 - val_loss: 0.4929
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9922 - loss: 0.5048 - val_accuracy: 0.9937 - val_loss: 0.4762
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9922 - loss: 0.4882 - val_accuracy: 0.9937 - val_loss: 0.4589
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9906 - loss: 0.4710 - val_accuracy: 0.9937 - val_loss: 0.4413
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9922 - loss: 0.4507 - val_accuracy: 0.9937 - val_loss: 0.4235
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9906 - loss: 0.4363 - val_accuracy: 0.9937 - val_loss: 0.4055
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9906 - loss: 0.4175 - val_accuracy: 0.9937 - val_loss: 0.3874
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9906 - loss: 0.4006 - val_accuracy: 0.9937 - val_loss: 0.3693
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9906 - loss: 0.3828 - val_accuracy: 0.9937 - val_loss: 0.3512
# [PAIR OM0 vs OM7] Test accuracy: 0.9949
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM7
#
# ================================================================================
# TRAINING: Agent OM0_vs_OM8
# ================================================================================
# [PAIR OM0 vs OM8] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM0 vs OM8] After balancing: #0=319, #1=319
# [PAIR OM0 vs OM8] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.5000 - loss: 0.6969 - val_accuracy: 0.4969 - val_loss: 0.6920
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5016 - loss: 0.6950 - val_accuracy: 0.4969 - val_loss: 0.6896
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5141 - loss: 0.6925 - val_accuracy: 0.4969 - val_loss: 0.6874
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5188 - loss: 0.6909 - val_accuracy: 0.4969 - val_loss: 0.6853
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5235 - loss: 0.6883 - val_accuracy: 0.5157 - val_loss: 0.6831
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5470 - loss: 0.6877 - val_accuracy: 0.5597 - val_loss: 0.6809
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5721 - loss: 0.6838 - val_accuracy: 0.6038 - val_loss: 0.6786
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5737 - loss: 0.6829 - val_accuracy: 0.6289 - val_loss: 0.6762
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5956 - loss: 0.6805 - val_accuracy: 0.6730 - val_loss: 0.6737
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6129 - loss: 0.6790 - val_accuracy: 0.6918 - val_loss: 0.6711
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6395 - loss: 0.6754 - val_accuracy: 0.7044 - val_loss: 0.6683
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6599 - loss: 0.6741 - val_accuracy: 0.7170 - val_loss: 0.6653
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6740 - loss: 0.6714 - val_accuracy: 0.7296 - val_loss: 0.6622
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6912 - loss: 0.6678 - val_accuracy: 0.7547 - val_loss: 0.6589
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6865 - loss: 0.6672 - val_accuracy: 0.7673 - val_loss: 0.6554
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7147 - loss: 0.6625 - val_accuracy: 0.7736 - val_loss: 0.6516
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7398 - loss: 0.6570 - val_accuracy: 0.7799 - val_loss: 0.6473
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7414 - loss: 0.6530 - val_accuracy: 0.7862 - val_loss: 0.6425
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7602 - loss: 0.6502 - val_accuracy: 0.7925 - val_loss: 0.6372
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7539 - loss: 0.6432 - val_accuracy: 0.7925 - val_loss: 0.6314
# [PAIR OM0 vs OM8] Test accuracy: 0.8182
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM0_vs_OM8
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM2
# ================================================================================
# [PAIR OM1 vs OM2] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM2] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM2] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.5235 - loss: 0.6988 - val_accuracy: 0.5220 - val_loss: 0.6994
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5674 - loss: 0.6922 - val_accuracy: 0.5346 - val_loss: 0.6907
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6458 - loss: 0.6836 - val_accuracy: 0.5975 - val_loss: 0.6810
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6818 - loss: 0.6799 - val_accuracy: 0.7987 - val_loss: 0.6709
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7288 - loss: 0.6734 - val_accuracy: 0.8805 - val_loss: 0.6603
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7806 - loss: 0.6645 - val_accuracy: 0.9686 - val_loss: 0.6490
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8229 - loss: 0.6522 - val_accuracy: 0.9560 - val_loss: 0.6368
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8495 - loss: 0.6436 - val_accuracy: 0.9497 - val_loss: 0.6243
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8668 - loss: 0.6324 - val_accuracy: 0.9497 - val_loss: 0.6114
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8856 - loss: 0.6221 - val_accuracy: 0.9497 - val_loss: 0.5980
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8652 - loss: 0.6089 - val_accuracy: 0.9371 - val_loss: 0.5842
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8934 - loss: 0.5974 - val_accuracy: 0.9371 - val_loss: 0.5698
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9107 - loss: 0.5830 - val_accuracy: 0.9308 - val_loss: 0.5542
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8966 - loss: 0.5703 - val_accuracy: 0.9308 - val_loss: 0.5381
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9060 - loss: 0.5588 - val_accuracy: 0.9308 - val_loss: 0.5218
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9075 - loss: 0.5414 - val_accuracy: 0.9308 - val_loss: 0.5055
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9091 - loss: 0.5261 - val_accuracy: 0.9308 - val_loss: 0.4893
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9154 - loss: 0.5143 - val_accuracy: 0.9308 - val_loss: 0.4732
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9060 - loss: 0.5002 - val_accuracy: 0.9308 - val_loss: 0.4571
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9044 - loss: 0.4840 - val_accuracy: 0.9308 - val_loss: 0.4410
# [PAIR OM1 vs OM2] Test accuracy: 0.9343
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM2
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM3
# ================================================================================
# [PAIR OM1 vs OM3] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM3] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM3] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5204 - loss: 0.6646 - val_accuracy: 0.5031 - val_loss: 0.6507
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5439 - loss: 0.6514 - val_accuracy: 0.5031 - val_loss: 0.6359
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5940 - loss: 0.6379 - val_accuracy: 0.7862 - val_loss: 0.6212
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6865 - loss: 0.6249 - val_accuracy: 0.8176 - val_loss: 0.6064
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7555 - loss: 0.6098 - val_accuracy: 0.8365 - val_loss: 0.5913
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7915 - loss: 0.5956 - val_accuracy: 0.8428 - val_loss: 0.5760
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8197 - loss: 0.5838 - val_accuracy: 0.8553 - val_loss: 0.5607
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8417 - loss: 0.5662 - val_accuracy: 0.8616 - val_loss: 0.5455
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8495 - loss: 0.5555 - val_accuracy: 0.8868 - val_loss: 0.5303
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8574 - loss: 0.5364 - val_accuracy: 0.8994 - val_loss: 0.5151
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8558 - loss: 0.5249 - val_accuracy: 0.8994 - val_loss: 0.5002
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8699 - loss: 0.5113 - val_accuracy: 0.8994 - val_loss: 0.4853
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8824 - loss: 0.4953 - val_accuracy: 0.9182 - val_loss: 0.4703
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8856 - loss: 0.4826 - val_accuracy: 0.9182 - val_loss: 0.4554
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8966 - loss: 0.4680 - val_accuracy: 0.9308 - val_loss: 0.4406
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9091 - loss: 0.4533 - val_accuracy: 0.9497 - val_loss: 0.4262
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9138 - loss: 0.4409 - val_accuracy: 0.9497 - val_loss: 0.4120
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9342 - loss: 0.4245 - val_accuracy: 0.9560 - val_loss: 0.3982
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9357 - loss: 0.4128 - val_accuracy: 0.9686 - val_loss: 0.3848
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9326 - loss: 0.3944 - val_accuracy: 0.9811 - val_loss: 0.3717
# [PAIR OM1 vs OM3] Test accuracy: 0.9747
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM3
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM4
# ================================================================================
# [PAIR OM1 vs OM4] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM4] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM4] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.5016 - loss: 0.7148 - val_accuracy: 0.5031 - val_loss: 0.7058
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5078 - loss: 0.7034 - val_accuracy: 0.5283 - val_loss: 0.6937
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5313 - loss: 0.6937 - val_accuracy: 0.6038 - val_loss: 0.6824
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5721 - loss: 0.6844 - val_accuracy: 0.6667 - val_loss: 0.6720
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6238 - loss: 0.6774 - val_accuracy: 0.6855 - val_loss: 0.6626
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6473 - loss: 0.6687 - val_accuracy: 0.7170 - val_loss: 0.6539
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6803 - loss: 0.6593 - val_accuracy: 0.7358 - val_loss: 0.6457
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7179 - loss: 0.6520 - val_accuracy: 0.7421 - val_loss: 0.6374
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7429 - loss: 0.6437 - val_accuracy: 0.7484 - val_loss: 0.6289
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.7461 - loss: 0.6371 - val_accuracy: 0.7610 - val_loss: 0.6201
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7665 - loss: 0.6277 - val_accuracy: 0.7736 - val_loss: 0.6109
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.7696 - loss: 0.6192 - val_accuracy: 0.7799 - val_loss: 0.6012
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7931 - loss: 0.6089 - val_accuracy: 0.7799 - val_loss: 0.5908
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7947 - loss: 0.5998 - val_accuracy: 0.7862 - val_loss: 0.5797
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8135 - loss: 0.5891 - val_accuracy: 0.8176 - val_loss: 0.5678
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8150 - loss: 0.5755 - val_accuracy: 0.8239 - val_loss: 0.5548
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8307 - loss: 0.5636 - val_accuracy: 0.8365 - val_loss: 0.5408
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8370 - loss: 0.5516 - val_accuracy: 0.8365 - val_loss: 0.5257
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8370 - loss: 0.5346 - val_accuracy: 0.8428 - val_loss: 0.5097
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8417 - loss: 0.5184 - val_accuracy: 0.8553 - val_loss: 0.4927
# [PAIR OM1 vs OM4] Test accuracy: 0.8687
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM4
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM5
# ================================================================================
# [PAIR OM1 vs OM5] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM5] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM5] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.8197 - loss: 0.6455 - val_accuracy: 0.8868 - val_loss: 0.6247
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8824 - loss: 0.6257 - val_accuracy: 0.9497 - val_loss: 0.6039
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9216 - loss: 0.6047 - val_accuracy: 0.9623 - val_loss: 0.5843
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9248 - loss: 0.5893 - val_accuracy: 0.9623 - val_loss: 0.5655
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9451 - loss: 0.5678 - val_accuracy: 0.9686 - val_loss: 0.5472
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9420 - loss: 0.5528 - val_accuracy: 0.9686 - val_loss: 0.5291
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9451 - loss: 0.5376 - val_accuracy: 0.9686 - val_loss: 0.5109
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9436 - loss: 0.5193 - val_accuracy: 0.9686 - val_loss: 0.4925
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9420 - loss: 0.5030 - val_accuracy: 0.9686 - val_loss: 0.4743
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9514 - loss: 0.4839 - val_accuracy: 0.9748 - val_loss: 0.4564
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9483 - loss: 0.4693 - val_accuracy: 0.9748 - val_loss: 0.4387
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9545 - loss: 0.4509 - val_accuracy: 0.9748 - val_loss: 0.4213
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9498 - loss: 0.4365 - val_accuracy: 0.9748 - val_loss: 0.4043
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9577 - loss: 0.4168 - val_accuracy: 0.9748 - val_loss: 0.3878
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9530 - loss: 0.4022 - val_accuracy: 0.9748 - val_loss: 0.3715
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9608 - loss: 0.3887 - val_accuracy: 0.9748 - val_loss: 0.3558
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9624 - loss: 0.3741 - val_accuracy: 0.9748 - val_loss: 0.3406
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9577 - loss: 0.3562 - val_accuracy: 0.9748 - val_loss: 0.3258
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9671 - loss: 0.3413 - val_accuracy: 0.9748 - val_loss: 0.3113
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9639 - loss: 0.3291 - val_accuracy: 0.9748 - val_loss: 0.2972
# [PAIR OM1 vs OM5] Test accuracy: 0.9798
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM5
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM6
# ================================================================================
# [PAIR OM1 vs OM6] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM6] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM6] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.8464 - loss: 0.6459 - val_accuracy: 0.9119 - val_loss: 0.6345
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8715 - loss: 0.6298 - val_accuracy: 0.9182 - val_loss: 0.6139
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8966 - loss: 0.6124 - val_accuracy: 0.9371 - val_loss: 0.5930
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9185 - loss: 0.5909 - val_accuracy: 0.9497 - val_loss: 0.5721
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9295 - loss: 0.5739 - val_accuracy: 0.9560 - val_loss: 0.5516
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9232 - loss: 0.5558 - val_accuracy: 0.9686 - val_loss: 0.5316
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9420 - loss: 0.5413 - val_accuracy: 0.9811 - val_loss: 0.5120
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9373 - loss: 0.5215 - val_accuracy: 0.9811 - val_loss: 0.4930
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9561 - loss: 0.5034 - val_accuracy: 0.9811 - val_loss: 0.4745
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9577 - loss: 0.4907 - val_accuracy: 0.9811 - val_loss: 0.4567
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9687 - loss: 0.4714 - val_accuracy: 0.9811 - val_loss: 0.4395
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9671 - loss: 0.4581 - val_accuracy: 0.9811 - val_loss: 0.4230
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9718 - loss: 0.4392 - val_accuracy: 0.9874 - val_loss: 0.4069
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9781 - loss: 0.4265 - val_accuracy: 0.9874 - val_loss: 0.3914
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9749 - loss: 0.4118 - val_accuracy: 0.9874 - val_loss: 0.3764
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9749 - loss: 0.3944 - val_accuracy: 0.9874 - val_loss: 0.3619
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9655 - loss: 0.3862 - val_accuracy: 0.9874 - val_loss: 0.3479
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9749 - loss: 0.3730 - val_accuracy: 0.9874 - val_loss: 0.3343
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9765 - loss: 0.3579 - val_accuracy: 0.9874 - val_loss: 0.3210
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9781 - loss: 0.3434 - val_accuracy: 0.9874 - val_loss: 0.3080
# [PAIR OM1 vs OM6] Test accuracy: 0.9899
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM6
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM7
# ================================================================================
# [PAIR OM1 vs OM7] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM7] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM7] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.3495 - loss: 0.7204 - val_accuracy: 0.4340 - val_loss: 0.7119
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.4389 - loss: 0.7023 - val_accuracy: 0.5597 - val_loss: 0.6935
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5611 - loss: 0.6855 - val_accuracy: 0.5849 - val_loss: 0.6757
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6458 - loss: 0.6711 - val_accuracy: 0.7547 - val_loss: 0.6585
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7962 - loss: 0.6551 - val_accuracy: 0.9874 - val_loss: 0.6420
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9060 - loss: 0.6419 - val_accuracy: 0.9937 - val_loss: 0.6263
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9514 - loss: 0.6271 - val_accuracy: 0.9937 - val_loss: 0.6105
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9671 - loss: 0.6113 - val_accuracy: 0.9937 - val_loss: 0.5948
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9859 - loss: 0.5991 - val_accuracy: 0.9937 - val_loss: 0.5792
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9828 - loss: 0.5811 - val_accuracy: 0.9937 - val_loss: 0.5623
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9843 - loss: 0.5677 - val_accuracy: 0.9937 - val_loss: 0.5448
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9922 - loss: 0.5501 - val_accuracy: 0.9937 - val_loss: 0.5267
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9875 - loss: 0.5298 - val_accuracy: 0.9937 - val_loss: 0.5078
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9906 - loss: 0.5154 - val_accuracy: 0.9937 - val_loss: 0.4886
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9922 - loss: 0.4959 - val_accuracy: 0.9937 - val_loss: 0.4690
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9890 - loss: 0.4751 - val_accuracy: 0.9937 - val_loss: 0.4490
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9922 - loss: 0.4551 - val_accuracy: 0.9937 - val_loss: 0.4287
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9906 - loss: 0.4377 - val_accuracy: 0.9937 - val_loss: 0.4083
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9890 - loss: 0.4190 - val_accuracy: 0.9937 - val_loss: 0.3878
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9906 - loss: 0.3981 - val_accuracy: 0.9937 - val_loss: 0.3675
# [PAIR OM1 vs OM7] Test accuracy: 0.9949
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM7
#
# ================================================================================
# TRAINING: Agent OM1_vs_OM8
# ================================================================================
# [PAIR OM1 vs OM8] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM1 vs OM8] After balancing: #0=319, #1=319
# [PAIR OM1 vs OM8] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.3856 - loss: 0.6994 - val_accuracy: 0.4151 - val_loss: 0.6941
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5094 - loss: 0.6910 - val_accuracy: 0.5597 - val_loss: 0.6844
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6426 - loss: 0.6818 - val_accuracy: 0.6981 - val_loss: 0.6749
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7382 - loss: 0.6747 - val_accuracy: 0.8113 - val_loss: 0.6656
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8103 - loss: 0.6647 - val_accuracy: 0.9057 - val_loss: 0.6562
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8511 - loss: 0.6555 - val_accuracy: 0.9371 - val_loss: 0.6468
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8856 - loss: 0.6477 - val_accuracy: 0.9560 - val_loss: 0.6372
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8997 - loss: 0.6380 - val_accuracy: 0.9560 - val_loss: 0.6271
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9232 - loss: 0.6274 - val_accuracy: 0.9623 - val_loss: 0.6163
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9263 - loss: 0.6194 - val_accuracy: 0.9686 - val_loss: 0.6048
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9263 - loss: 0.6103 - val_accuracy: 0.9686 - val_loss: 0.5928
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9373 - loss: 0.5959 - val_accuracy: 0.9686 - val_loss: 0.5799
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9436 - loss: 0.5860 - val_accuracy: 0.9686 - val_loss: 0.5663
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9389 - loss: 0.5710 - val_accuracy: 0.9748 - val_loss: 0.5519
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9451 - loss: 0.5577 - val_accuracy: 0.9748 - val_loss: 0.5365
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9483 - loss: 0.5419 - val_accuracy: 0.9748 - val_loss: 0.5203
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9467 - loss: 0.5284 - val_accuracy: 0.9811 - val_loss: 0.5031
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9530 - loss: 0.5103 - val_accuracy: 0.9811 - val_loss: 0.4849
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9561 - loss: 0.4952 - val_accuracy: 0.9811 - val_loss: 0.4658
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9561 - loss: 0.4754 - val_accuracy: 0.9811 - val_loss: 0.4459
# [PAIR OM1 vs OM8] Test accuracy: 0.9747
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM1_vs_OM8
#
# ================================================================================
# TRAINING: Agent OM2_vs_OM3
# ================================================================================
# [PAIR OM2 vs OM3] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM2 vs OM3] After balancing: #0=319, #1=319
# [PAIR OM2 vs OM3] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9107 - loss: 0.6331 - val_accuracy: 0.9937 - val_loss: 0.6145
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9514 - loss: 0.6090 - val_accuracy: 0.9937 - val_loss: 0.5911
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9734 - loss: 0.5883 - val_accuracy: 0.9937 - val_loss: 0.5686
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9796 - loss: 0.5687 - val_accuracy: 0.9811 - val_loss: 0.5465
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9718 - loss: 0.5491 - val_accuracy: 0.9811 - val_loss: 0.5249
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9639 - loss: 0.5301 - val_accuracy: 0.9811 - val_loss: 0.5036
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9592 - loss: 0.5080 - val_accuracy: 0.9811 - val_loss: 0.4825
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9624 - loss: 0.4859 - val_accuracy: 0.9811 - val_loss: 0.4616
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9514 - loss: 0.4677 - val_accuracy: 0.9811 - val_loss: 0.4409
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9592 - loss: 0.4483 - val_accuracy: 0.9748 - val_loss: 0.4206
# Epoch 11/20
# ...
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7320 - loss: 0.6376 - val_accuracy: 0.7484 - val_loss: 0.6221
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7351 - loss: 0.6313 - val_accuracy: 0.7610 - val_loss: 0.6118
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7367 - loss: 0.6214 - val_accuracy: 0.7610 - val_loss: 0.6008
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7774 - loss: 0.6084 - val_accuracy: 0.7673 - val_loss: 0.5892
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7712 - loss: 0.5996 - val_accuracy: 0.7673 - val_loss: 0.5776
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7774 - loss: 0.5892 - val_accuracy: 0.7925 - val_loss: 0.5657
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7774 - loss: 0.5730 - val_accuracy: 0.7987 - val_loss: 0.5526
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7915 - loss: 0.5647 - val_accuracy: 0.7987 - val_loss: 0.5384
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8009 - loss: 0.5503 - val_accuracy: 0.8113 - val_loss: 0.5233
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8072 - loss: 0.5402 - val_accuracy: 0.8302 - val_loss: 0.5074
# [PAIR OM5 vs OM7] Test accuracy: 0.8636
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM5_vs_OM7
#
# ================================================================================
# TRAINING: Agent OM5_vs_OM8
# ================================================================================
# [PAIR OM5 vs OM8] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM5 vs OM8] After balancing: #0=319, #1=319
# [PAIR OM5 vs OM8] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.5000 - loss: 0.6676 - val_accuracy: 0.4969 - val_loss: 0.6593
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5000 - loss: 0.6550 - val_accuracy: 0.4969 - val_loss: 0.6457
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5000 - loss: 0.6429 - val_accuracy: 0.4969 - val_loss: 0.6325
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5000 - loss: 0.6315 - val_accuracy: 0.4969 - val_loss: 0.6197
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5031 - loss: 0.6197 - val_accuracy: 0.4969 - val_loss: 0.6073
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5078 - loss: 0.6069 - val_accuracy: 0.4969 - val_loss: 0.5951
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5298 - loss: 0.5974 - val_accuracy: 0.5535 - val_loss: 0.5832
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5705 - loss: 0.5851 - val_accuracy: 0.6855 - val_loss: 0.5714
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6144 - loss: 0.5745 - val_accuracy: 0.7987 - val_loss: 0.5598
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6771 - loss: 0.5637 - val_accuracy: 0.8805 - val_loss: 0.5482
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7743 - loss: 0.5515 - val_accuracy: 0.9245 - val_loss: 0.5368
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7962 - loss: 0.5440 - val_accuracy: 0.9434 - val_loss: 0.5256
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8386 - loss: 0.5331 - val_accuracy: 0.9748 - val_loss: 0.5145
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8746 - loss: 0.5248 - val_accuracy: 0.9748 - val_loss: 0.5037
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8997 - loss: 0.5122 - val_accuracy: 0.9811 - val_loss: 0.4930
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9232 - loss: 0.5029 - val_accuracy: 0.9874 - val_loss: 0.4826
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9373 - loss: 0.4919 - val_accuracy: 0.9811 - val_loss: 0.4724
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9498 - loss: 0.4854 - val_accuracy: 0.9811 - val_loss: 0.4624
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9373 - loss: 0.4760 - val_accuracy: 0.9811 - val_loss: 0.4526
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9577 - loss: 0.4643 - val_accuracy: 0.9811 - val_loss: 0.4429
# [PAIR OM5 vs OM8] Test accuracy: 0.9899
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM5_vs_OM8
#
# ================================================================================
# TRAINING: Agent OM6_vs_OM7
# ================================================================================
# [PAIR OM6 vs OM7] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM6 vs OM7] After balancing: #0=319, #1=319
# [PAIR OM6 vs OM7] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.4969 - loss: 0.6846 - val_accuracy: 0.4969 - val_loss: 0.6803
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5439 - loss: 0.6781 - val_accuracy: 0.5849 - val_loss: 0.6740
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5862 - loss: 0.6714 - val_accuracy: 0.6478 - val_loss: 0.6676
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6238 - loss: 0.6659 - val_accuracy: 0.6478 - val_loss: 0.6607
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6066 - loss: 0.6617 - val_accuracy: 0.6541 - val_loss: 0.6534
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6317 - loss: 0.6540 - val_accuracy: 0.6541 - val_loss: 0.6462
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6646 - loss: 0.6465 - val_accuracy: 0.6541 - val_loss: 0.6384
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6505 - loss: 0.6400 - val_accuracy: 0.6541 - val_loss: 0.6299
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6708 - loss: 0.6342 - val_accuracy: 0.6855 - val_loss: 0.6211
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6928 - loss: 0.6234 - val_accuracy: 0.6855 - val_loss: 0.6121
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7194 - loss: 0.6150 - val_accuracy: 0.6792 - val_loss: 0.6026
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7053 - loss: 0.6066 - val_accuracy: 0.6981 - val_loss: 0.5925
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7429 - loss: 0.5930 - val_accuracy: 0.7233 - val_loss: 0.5818
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7665 - loss: 0.5836 - val_accuracy: 0.7484 - val_loss: 0.5704
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7743 - loss: 0.5725 - val_accuracy: 0.7799 - val_loss: 0.5584
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7837 - loss: 0.5624 - val_accuracy: 0.7987 - val_loss: 0.5457
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7868 - loss: 0.5507 - val_accuracy: 0.8050 - val_loss: 0.5326
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8197 - loss: 0.5356 - val_accuracy: 0.7987 - val_loss: 0.5191
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8182 - loss: 0.5238 - val_accuracy: 0.8176 - val_loss: 0.5051
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8260 - loss: 0.5113 - val_accuracy: 0.8239 - val_loss: 0.4904
# [PAIR OM6 vs OM7] Test accuracy: 0.8485
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM6_vs_OM7
#
# ================================================================================
# TRAINING: Agent OM6_vs_OM8
# ================================================================================
# [PAIR OM6 vs OM8] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM6 vs OM8] After balancing: #0=319, #1=319
# [PAIR OM6 vs OM8] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 125ms/step - accuracy: 0.7038 - loss: 0.6833 - val_accuracy: 0.9497 - val_loss: 0.6758
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7821 - loss: 0.6713 - val_accuracy: 0.9686 - val_loss: 0.6606
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8621 - loss: 0.6571 - val_accuracy: 0.9560 - val_loss: 0.6457
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8793 - loss: 0.6450 - val_accuracy: 0.9497 - val_loss: 0.6310
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9013 - loss: 0.6284 - val_accuracy: 0.9434 - val_loss: 0.6170
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8981 - loss: 0.6172 - val_accuracy: 0.9308 - val_loss: 0.6035
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8871 - loss: 0.6054 - val_accuracy: 0.9182 - val_loss: 0.5902
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8887 - loss: 0.5925 - val_accuracy: 0.9182 - val_loss: 0.5769
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8887 - loss: 0.5808 - val_accuracy: 0.9182 - val_loss: 0.5637
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8871 - loss: 0.5685 - val_accuracy: 0.9182 - val_loss: 0.5507
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8871 - loss: 0.5556 - val_accuracy: 0.9182 - val_loss: 0.5379
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8871 - loss: 0.5455 - val_accuracy: 0.9182 - val_loss: 0.5250
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8887 - loss: 0.5307 - val_accuracy: 0.9119 - val_loss: 0.5120
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8840 - loss: 0.5181 - val_accuracy: 0.9119 - val_loss: 0.4989
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8871 - loss: 0.5070 - val_accuracy: 0.9119 - val_loss: 0.4858
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8887 - loss: 0.4935 - val_accuracy: 0.9119 - val_loss: 0.4728
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8887 - loss: 0.4802 - val_accuracy: 0.9119 - val_loss: 0.4597
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8903 - loss: 0.4696 - val_accuracy: 0.9119 - val_loss: 0.4466
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8903 - loss: 0.4568 - val_accuracy: 0.9119 - val_loss: 0.4336
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8903 - loss: 0.4429 - val_accuracy: 0.9119 - val_loss: 0.4206
# [PAIR OM6 vs OM8] Test accuracy: 0.9040
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM6_vs_OM8
#
# ================================================================================
# TRAINING: Agent OM7_vs_OM8
# ================================================================================
# [PAIR OM7 vs OM8] X_seq=(990, 10, 18), y_seq=(990,), #0=491, #1=499
# [PAIR OM7 vs OM8] After balancing: #0=319, #1=319
# [PAIR OM7 vs OM8] Training LSTM...
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.6818 - loss: 0.6764 - val_accuracy: 0.8113 - val_loss: 0.6692
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7947 - loss: 0.6635 - val_accuracy: 0.8491 - val_loss: 0.6558
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8480 - loss: 0.6524 - val_accuracy: 0.8868 - val_loss: 0.6421
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8809 - loss: 0.6399 - val_accuracy: 0.9245 - val_loss: 0.6285
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9091 - loss: 0.6273 - val_accuracy: 0.9245 - val_loss: 0.6151
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9295 - loss: 0.6157 - val_accuracy: 0.9371 - val_loss: 0.6017
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9389 - loss: 0.6010 - val_accuracy: 0.9623 - val_loss: 0.5884
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9608 - loss: 0.5893 - val_accuracy: 0.9811 - val_loss: 0.5747
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9592 - loss: 0.5796 - val_accuracy: 0.9937 - val_loss: 0.5608
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9749 - loss: 0.5626 - val_accuracy: 0.9937 - val_loss: 0.5463
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9718 - loss: 0.5481 - val_accuracy: 0.9937 - val_loss: 0.5311
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9796 - loss: 0.5346 - val_accuracy: 0.9937 - val_loss: 0.5151
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9796 - loss: 0.5172 - val_accuracy: 0.9937 - val_loss: 0.4983
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9812 - loss: 0.5030 - val_accuracy: 0.9937 - val_loss: 0.4809
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9812 - loss: 0.4853 - val_accuracy: 0.9937 - val_loss: 0.4628
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9859 - loss: 0.4644 - val_accuracy: 0.9937 - val_loss: 0.4441
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9859 - loss: 0.4512 - val_accuracy: 0.9937 - val_loss: 0.4249
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9875 - loss: 0.4287 - val_accuracy: 0.9937 - val_loss: 0.4052
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9859 - loss: 0.4148 - val_accuracy: 0.9937 - val_loss: 0.3851
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9890 - loss: 0.3914 - val_accuracy: 0.9937 - val_loss: 0.3648
# [PAIR OM7 vs OM8] Test accuracy: 0.9949
# [MQTT] Publish summary -> fault_detection/report/pairwise/Agent_OM7_vs_OM8
#
# [TRAIN] Pairwise summary:
#           Pair   TestAcc
# 0   OM0_vs_OM1  0.979798
# 1   OM0_vs_OM2  0.959596
# 2   OM0_vs_OM3  0.994949
# 3   OM0_vs_OM4  0.787879
# 4   OM0_vs_OM5  0.979798
# 5   OM0_vs_OM6  0.939394
# 6   OM0_vs_OM7  0.994949
# 7   OM0_vs_OM8  0.818182
# 8   OM1_vs_OM2  0.934343
# 9   OM1_vs_OM3  0.974747
# 10  OM1_vs_OM4  0.868687
# 11  OM1_vs_OM5  0.979798
# 12  OM1_vs_OM6  0.989899
# 13  OM1_vs_OM7  0.994949
# 14  OM1_vs_OM8  0.974747
# 15  OM2_vs_OM3  0.974747
# 16  OM2_vs_OM4  0.944444
# 17  OM2_vs_OM5  0.979798
# 18  OM2_vs_OM6  0.984848
# 19  OM2_vs_OM7  0.994949
# 20  OM2_vs_OM8  0.929293
# 21  OM3_vs_OM4  0.994949
# 22  OM3_vs_OM5  0.979798
# 23  OM3_vs_OM6  0.883838
# 24  OM3_vs_OM7  0.979798
# 25  OM3_vs_OM8  0.994949
# 26  OM4_vs_OM5  0.979798
# 27  OM4_vs_OM6  0.934343
# 28  OM4_vs_OM7  0.994949
# 29  OM4_vs_OM8  0.919192
# 30  OM5_vs_OM6  0.555556
# 31  OM5_vs_OM7  0.863636
# 32  OM5_vs_OM8  0.989899
# 33  OM6_vs_OM7  0.848485
# 34  OM6_vs_OM8  0.904040
# 35  OM7_vs_OM8  0.994949
# [LIVE] Loading model for pair OM0 vs OM1
# [LIVE] Loading model for pair OM0 vs OM2
# [LIVE] Loading model for pair OM0 vs OM3
# [LIVE] Loading model for pair OM0 vs OM4
# [LIVE] Loading model for pair OM0 vs OM5
# [LIVE] Loading model for pair OM0 vs OM6
# [LIVE] Loading model for pair OM0 vs OM7
# [LIVE] Loading model for pair OM0 vs OM8
# [LIVE] Loading model for pair OM1 vs OM2
# [LIVE] Loading model for pair OM1 vs OM3
# [LIVE] Loading model for pair OM1 vs OM4
# [LIVE] Loading model for pair OM1 vs OM5
# [LIVE] Loading model for pair OM1 vs OM6
# [LIVE] Loading model for pair OM1 vs OM7
# [LIVE] Loading model for pair OM1 vs OM8
# [LIVE] Loading model for pair OM2 vs OM3
# [LIVE] Loading model for pair OM2 vs OM4
# [LIVE] Loading model for pair OM2 vs OM5
# [LIVE] Loading model for pair OM2 vs OM6
# [LIVE] Loading model for pair OM2 vs OM7
# [LIVE] Loading model for pair OM2 vs OM8
# [LIVE] Loading model for pair OM3 vs OM4
# [LIVE] Loading model for pair OM3 vs OM5
# [LIVE] Loading model for pair OM3 vs OM6
# [LIVE] Loading model for pair OM3 vs OM7
# [LIVE] Loading model for pair OM3 vs OM8
# [LIVE] Loading model for pair OM4 vs OM5
# [LIVE] Loading model for pair OM4 vs OM6
# [LIVE] Loading model for pair OM4 vs OM7
# [LIVE] Loading model for pair OM4 vs OM8
# [LIVE] Loading model for pair OM5 vs OM6
# [LIVE] Loading model for pair OM5 vs OM7
# [LIVE] Loading model for pair OM5 vs OM8
# [LIVE] Loading model for pair OM6 vs OM7
# [LIVE] Loading model for pair OM6 vs OM8
# [LIVE] Loading model for pair OM7 vs OM8
# [LIVE] Using features (18): ['Time', 'Data_ 1', 'Data_ 2', 'Data_ 3', 'Data_ 4', 'Data_ 5', 'Data_ 6', 'Data_ 7', 'Data_ 8', 'Data_ 9', 'Data_10', 'Data_11', 'Data_12', 'Data_13', 'Data_14', 'Data_15', 'Data_16', 'Data_17']
# [LIVE] Loaded 36 pairwise agents.
# [LIVE] Listening on fault_detection/live/features...

# %%
import lstm_pairwise_main

# %%
lstm_pairwise_main.RUN_TRAINING = True
lstm_pairwise_main.main()   # cell will run until you stop it
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 lstm_pairwise_main.RUN_TRAINING = True
#       2 lstm_pairwise_main.main()   # cell will run until you stop it
#
# NameError: name 'lstm_pairwise_main' is not defined
